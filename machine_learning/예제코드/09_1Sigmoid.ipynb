# %%
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt

# 데이터 생성
X, y = make_moons(n_samples=100, noise=0.25, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# 인공신경망 모델 생성 및 학습
mlp = MLPClassifier(hidden_layer_sizes=(10,), activation='logistic', max_iter=10000, random_state=42)
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(10,), max_iter=10000,
#               random_state=42)

# %%
# 정확도 출력
print("훈련 세트 정확도: {:.2f}".format(mlp.score(X_train, y_train)))
print("테스트 세트 정확도: {:.2f}".format(mlp.score(X_test, y_test)))

# 결정 경계 시각화
xx, yy = np.meshgrid(np.linspace(X[:, 0].min() - 1, X[:, 0].max() + 1, 100),
                     np.linspace(X[:, 1].min() - 1, X[:, 1].max() + 1, 100))
Z = mlp.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k')
plt.title("ANN with Sigmoid Activation")
plt.show()
# Out:
# 훈련 세트 정확도: 0.81
# 테스트 세트 정확도: 0.96

# %%
# Hard Sigmoid

import numpy as np
from sklearn.datasets import make_moons
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

def hard_sigmoid(x):
    return np.clip(0.2 * x + 0.5, 0, 1)

# make_moons 데이터 생성
X, y = make_moons(n_samples=500, noise=0.3, random_state=42)

# hard_sigmoid 적용
X_transformed = hard_sigmoid(X)

# 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2, random_state=42)

# %%
# MLP 분류기 생성
mlp = MLPClassifier(hidden_layer_sizes=(10,), activation='logistic', max_iter=10000, random_state=42)
mlp.fit(X_train, y_train)

# 시각화
plt.figure(figsize=(8, 6))
plt.scatter(X_transformed[y == 0][:, 0], X_transformed[y == 0][:, 1], color='red', label='Class 0')
plt.scatter(X_transformed[y == 1][:, 0], X_transformed[y == 1][:, 1], color='blue', label='Class 1')
plt.legend()
plt.title('make_moons dataset with hard_sigmoid')
plt.show()

# %%
# [참고] make_mmons 데이터 확인

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# make_moons 데이터 생성
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)

# 데이터 시각화
plt.scatter(X[y == 0, 0], X[y == 0, 1], color='red', marker='o', label='Class 0')
plt.scatter(X[y == 1, 0], X[y == 1, 1], color='blue', marker='s', label='Class 1')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend(loc='upper right')
plt.title('make_moons Data')
plt.show()
